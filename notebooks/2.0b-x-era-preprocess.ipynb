# %% [markdown]
# # ERA5 Preprocessing
#
# The purpose of this notebook is to read the ERA5 data from a remote web location, process them, and export the precipitation into flat parquet files.

# %%
# test = ERA.xload_rain_dataset()

# %%
# test.sel(time='1979-11')
# Out:
# <xarray.DataArray 'total_precipitation' (time: 720, lat: 99, lon: 233)> Size: 66MB
# dask.array<getitem, shape=(720, 99, 233), dtype=float32, chunksize=(48, 99, 233), chunktype=numpy.ndarray>
# Coordinates:
#   * lat      (lat) float32 396B 25.0 25.25 25.5 25.75 ... 48.75 49.0 49.25 49.5
#   * lon      (lon) float32 932B 235.0 235.2 235.5 235.8 ... 292.5 292.8 293.0
#   * time     (time) datetime64[ns] 6kB 1979-11-01 ... 1979-11-30T23:00:00
# Attributes:
#     long_name:   Total precipitation
#     short_name:  tp
#     units:       m

# %%
import xarray as xr

xr.open_dataset('/home1/07989/clin265/SCRATCH/hindcast/xarray/era_stage2/era_rain_2023-12.nc')
# Out:
# <xarray.Dataset> Size: 3MB
# Dimensions:              (time: 31, lat: 99, lon: 233)
# Coordinates:
#   * lat                  (lat) float32 396B 25.0 25.25 25.5 ... 49.0 49.25 49.5
#   * lon                  (lon) float32 932B 235.0 235.2 235.5 ... 292.8 293.0
#   * time                 (time) datetime64[ns] 248B 2023-12-01 ... 2023-12-31
# Data variables:
#     total_precipitation  (time, lat, lon) float32 3MB ...

# %%
xr.open_dataset('/home1/07989/clin265/SCRATCH/hindcast/xarray/stage2/surface_variables_rain_2023-12.nc')
# Out:
# <xarray.Dataset> Size: 23MB
# Dimensions:    (date: 31, lead_time: 8, lat: 99, lon: 233)
# Coordinates:
#   * lat        (lat) float64 792B 25.0 25.25 25.5 25.75 ... 49.0 49.25 49.5
#   * lon        (lon) float64 2kB 235.0 235.2 235.5 235.8 ... 292.5 292.8 293.0
#   * lead_time  (lead_time) timedelta64[ns] 64B 0 days 1 days ... 6 days 7 days
#   * date       (date) datetime64[ns] 248B 2023-12-01 2023-12-02 ... 2023-12-31
# Data variables:
#     tp06       (date, lead_time, lat, lon) float32 23MB ...

# %%
# sorted(set(str(date.astype('datetime64[D]')) for date in test.time.values))
# Out:
# ['1978-12-31',
#  '1979-01-01',
#  '1979-01-02',
#  '1979-01-03',
#  '1979-01-04',
#  '1979-01-05',
#  '1979-01-06',
#  '1979-01-07',
#  '1979-01-08',
#  '1979-01-09',
#  '1979-01-10',
#  '1979-01-11',
#  '1979-01-12',
#  '1979-01-13',
#  '1979-01-14',
#  '1979-01-15',
#  '1979-01-16',
#  '1979-01-17',
#  '1979-01-18',
#  '1979-01-19',
#  '1979-01-20',
#  '1979-01-21',
#  '1979-01-22',
#  '1979-01-23',
#  '1979-01-24',
#  '1979-01-25',
#  '1979-01-26',
#  '1979-01-27',
#  '1979-01-28',
#  '1979-01-29',
#  '1979-01-30',
#  '1979-01-31',
#  '1979-02-01',
#  '1979-02-02',
#  '1979-02-03',
#  '1979-02-04',
#  '1979-02-05',
#  '1979-02-06',
#  '1979-02-07',
#  '1979-02-08',
#  '1979-02-09',
#  '1979-02-10',
#  '1979-02-11',
#  '1979-02-12',
#  '1979-02-13',
#  '1979-02-14',
#  '1979-02-15',
#  '1979-02-16',
#  '1979-02-17',
#  '1979-02-18',
#  '1979-02-19',
#  '1979-02-20',
#  '1979-02-21',
#  '1979-02-22',
#  '1979-02-23',
#  '1979-02-24',
#  '1979-02-25',
#  '1979-02-26',
#  '1979-02-27',
#  '1979-02-28',
#  '1979-03-01',
#  '1979-03-02',
#  '1979-03-03',
#  '1979-03-04',
#  '1979-03-05',
#  '1979-03-06',
#  '1979-03-07',
#  '1979-03-08',
#  '1979-03-09',
#  '1979-03-10',
#  '1979-03-11',
#  '1979-03-12',
#  '1979-03-13',
#  '1979-03-14',
#  '1979-03-15',
#  '1979-03-16',
#  '1979-03-17',
#  '1979-03-18',
#  '1979-03-19',
#  '1979-03-20',
#  '1979-03-21',
#  '1979-03-22',
#  '1979-03-23',
#  '1979-03-24',
#  '1979-03-25',
#  '1979-03-26',
#  '1979-03-27',
#  '1979-03-28',
#  '1979-03-29',
#  '1979-03-30',
#  '1979-03-31',
#  '1979-04-01',
#  '1979-04-02',
#  '1979-04-03',
#  '1979-04-04',
#  '1979-04-05',
#  '1979-04-06',
#  '1979-04-07',
#  '1979-04-08',
#  '1979-04-09',
#  '1979-04-10',
#  '1979-04-11',
#  '1979-04-12',
#  '1979-04-13',
#  '1979-04-14',
#  '1979-04-15',
#  '1979-04-16',
#  '1979-04-17',
#  '1979-04-18',
#  '1979-04-19',
#  '1979-04-20',
#  '1979-04-21',
#  '1979-04-22',
#  '1979-04-23',
#  '1979-04-24',
#  '1979-04-25',
#  '1979-04-26',
#  '1979-04-27',
#  '1979-04-28',
#  '1979-04-29',
#  '1979-04-30',
#  '1979-05-01',
#  '1979-05-02',
#  '1979-05-03',
#  '1979-05-04',
#  '1979-05-05',
#  '1979-05-06',
#  '1979-05-07',
#  '1979-05-08',
#  '1979-05-09',
#  '1979-05-10',
#  '1979-05-11',
#  '1979-05-12',
#  '1979-05-13',
#  '1979-05-14',
#  '1979-05-15',
#  '1979-05-16',
#  '1979-05-17',
#  '1979-05-18',
#  '1979-05-19',
#  '1979-05-20',
#  '1979-05-21',
#  '1979-05-22',
#  '1979-05-23',
#  '1979-05-24',
#  '1979-05-25',
#  '1979-05-26',
#  '1979-05-27',
#  '1979-05-28',
#  '1979-05-29',
#  '1979-05-30',
#  '1979-05-31',
#  '1979-06-01',
#  '1979-06-02',
#  '1979-06-03',
#  '1979-06-04',
#  '1979-06-05',
#  '1979-06-06',
#  '1979-06-07',
#  '1979-06-08',
#  '1979-06-09',
#  '1979-06-10',
#  '1979-06-11',
#  '1979-06-12',
#  '1979-06-13',
#  '1979-06-14',
#  '1979-06-15',
#  '1979-06-16',
#  '1979-06-17',
#  '1979-06-18',
#  '1979-06-19',
#  '1979-06-20',
#  '1979-06-21',
#  '1979-06-22',
#  '1979-06-23',
#  '1979-06-24',
#  '1979-06-25',
#  '1979-06-26',
#  '1979-06-27',
#  '1979-06-28',
#  '1979-06-29',
#  '1979-06-30',
#  '1979-07-01',
#  '1979-07-02',
#  '1979-07-03',
#  '1979-07-04',
#  '1979-07-05',
#  '1979-07-06',
#  '1979-07-07',
#  '1979-07-08',
#  '1979-07-09',
#  '1979-07-10',
#  '1979-07-11',
#  '1979-07-12',
#  '1979-07-13',
#  '1979-07-14',
#  '1979-07-15',
#  '1979-07-16',
#  '1979-07-17',
#  '1979-07-18',
#  '1979-07-19',
#  '1979-07-20',
#  '1979-07-21',
#  '1979-07-22',
#  '1979-07-23',
#  '1979-07-24',
#  '1979-07-25',
#  '1979-07-26',
#  '1979-07-27',
#  '1979-07-28',
#  '1979-07-29',
#  '1979-07-30',
#  '1979-07-31',
#  '1979-08-01',
#  '1979-08-02',
#  '1979-08-03',
#  '1979-08-04',
#  '1979-08-05',
#  '1979-08-06',
#  '1979-08-07',
#  '1979-08-08',
#  '1979-08-09',
#  '1979-08-10',
#  '1979-08-11',
#  '1979-08-12',
#  '1979-08-13',
#  '1979-08-14',
#  '1979-08-15',
#  '1979-08-16',
#  '1979-08-17',
#  '1979-08-18',
#  '1979-08-19',
#  '1979-08-20',
#  '1979-08-21',
#  '1979-08-22',
#  '1979-08-23',
#  '1979-08-24',
#  '1979-08-25',
#  '1979-08-26',
#  '1979-08-27',
#  '1979-08-28',
#  '1979-08-29',
#  '1979-08-30',
#  '1979-08-31',
#  '1979-09-01',
#  '1979-09-02',
#  '1979-09-03',
#  '1979-09-04',
#  '1979-09-05',
#  '1979-09-06',
#  '1979-09-07',
#  '1979-09-08',
#  '1979-09-09',
#  '1979-09-10',
#  '1979-09-11',
#  '1979-09-12',
#  '1979-09-13',
#  '1979-09-14',
#  '1979-09-15',
#  '1979-09-16',
#  '1979-09-17',
#  '1979-09-18',
#  '1979-09-19',
#  '1979-09-20',
#  '1979-09-21',
#  '1979-09-22',
#  '1979-09-23',
#  '1979-09-24',
#  '1979-09-25',
#  '1979-09-26',
#  '1979-09-27',
#  '1979-09-28',
#  '1979-09-29',
#  '1979-09-30',
#  '1979-10-01',
#  '1979-10-02',
#  '1979-10-03',
#  '1979-10-04',
#  '1979-10-05',
#  '1979-10-06',
#  '1979-10-07',
#  '1979-10-08',
#  '1979-10-09',
#  '1979-10-10',
#  '1979-10-11',
#  '1979-10-12',
#  '1979-10-13',
#  '1979-10-14',
#  '1979-10-15',
#  '1979-10-16',
#  '1979-10-17',
#  '1979-10-18',
#  '1979-10-19',
#  '1979-10-20',
#  '1979-10-21',
#  '1979-10-22',
#  '1979-10-23',
#  '1979-10-24',
#  '1979-10-25',
#  '1979-10-26',
#  '1979-10-27',
#  '1979-10-28',
#  '1979-10-29',
#  '1979-10-30',
#  '1979-10-31',
#  '1979-11-01',
#  '1979-11-02',
#  '1979-11-03',
#  '1979-11-04',
#  '1979-11-05',
#  '1979-11-06',
#  '1979-11-07',
#  '1979-11-08',
#  '1979-11-09',
#  '1979-11-10',
#  '1979-11-11',
#  '1979-11-12',
#  '1979-11-13',
#  '1979-11-14',
#  '1979-11-15',
#  '1979-11-16',
#  '1979-11-17',
#  '1979-11-18',
#  '1979-11-19',
#  '1979-11-20',
#  '1979-11-21',
#  '1979-11-22',
#  '1979-11-23',
#  '1979-11-24',
#  '1979-11-25',
#  '1979-11-26',
#  '1979-11-27',
#  '1979-11-28',
#  '1979-11-29',
#  '1979-11-30',
#  '1979-12-01',
#  '1979-12-02',
#  '1979-12-03',
#  '1979-12-04',
#  '1979-12-05',
#  '1979-12-06',
#  '1979-12-07',
#  '1979-12-08',
#  '1979-12-09',
#  '1979-12-10',
#  '1979-12-11',
#  '1979-12-12',
#  '1979-12-13',
#  '1979-12-14',
#  '1979-12-15',
#  '1979-12-16',
#  '1979-12-17',
#  '1979-12-18',
#  '1979-12-19',
#  '1979-12-20',
#  '1979-12-21',
#  '1979-12-22',
#  '1979-12-23',
#  '1979-12-24',
#  '1979-12-25',
#  '1979-12-26',
#  '1979-12-27',
#  '1979-12-28',
#  '1979-12-29',
#  '1979-12-30',
#  '1979-12-31',
#  '1980-01-01',
#  '1980-01-02',
#  '1980-01-03',
#  '1980-01-04',
#  '1980-01-05',
#  '1980-01-06',
#  '1980-01-07',
#  '1980-01-08',
#  '1980-01-09',
#  '1980-01-10',
#  '1980-01-11',
#  '1980-01-12',
#  '1980-01-13',
#  '1980-01-14',
#  '1980-01-15',
#  '1980-01-16',
#  '1980-01-17',
#  '1980-01-18',
#  '1980-01-19',
#  '1980-01-20',
#  '1980-01-21',
#  '1980-01-22',
#  '1980-01-23',
#  '1980-01-24',
#  '1980-01-25',
#  '1980-01-26',
#  '1980-01-27',
#  '1980-01-28',
#  '1980-01-29',
#  '1980-01-30',
#  '1980-01-31',
#  '1980-02-01',
#  '1980-02-02',
#  '1980-02-03',
#  '1980-02-04',
#  '1980-02-05',
#  '1980-02-06',
#  '1980-02-07',
#  '1980-02-08',
#  '1980-02-09',
#  '1980-02-10',
#  '1980-02-11',
#  '1980-02-12',
#  '1980-02-13',
#  '1980-02-14',
#  '1980-02-15',
#  '1980-02-16',
#  '1980-02-17',
#  '1980-02-18',
#  '1980-02-19',
#  '1980-02-20',
#  '1980-02-21',
#  '1980-02-22',
#  '1980-02-23',
#  '1980-02-24',
#  '1980-02-25',
#  '1980-02-26',
#  '1980-02-27',
#  '1980-02-28',
#  '1980-02-29',
#  '1980-03-01',
#  '1980-03-02',
#  '1980-03-03',
#  '1980-03-04',
#  '1980-03-05',
#  '1980-03-06',
#  '1980-03-07',
#  '1980-03-08',
#  '1980-03-09',
#  '1980-03-10',
#  '1980-03-11',
#  '1980-03-12',
#  '1980-03-13',
#  '1980-03-14',
#  '1980-03-15',
#  '1980-03-16',
#  '1980-03-17',
#  '1980-03-18',
#  '1980-03-19',
#  '1980-03-20',
#  '1980-03-21',
#  '1980-03-22',
#  '1980-03-23',
#  '1980-03-24',
#  '1980-03-25',
#  '1980-03-26',
#  '1980-03-27',
#  '1980-03-28',
#  '1980-03-29',
#  '1980-03-30',
#  '1980-03-31',
#  '1980-04-01',
#  '1980-04-02',
#  '1980-04-03',
#  '1980-04-04',
#  '1980-04-05',
#  '1980-04-06',
#  '1980-04-07',
#  '1980-04-08',
#  '1980-04-09',
#  '1980-04-10',
#  '1980-04-11',
#  '1980-04-12',
#  '1980-04-13',
#  '1980-04-14',
#  '1980-04-15',
#  '1980-04-16',
#  '1980-04-17',
#  '1980-04-18',
#  '1980-04-19',
#  '1980-04-20',
#  '1980-04-21',
#  '1980-04-22',
#  '1980-04-23',
#  '1980-04-24',
#  '1980-04-25',
#  '1980-04-26',
#  '1980-04-27',
#  '1980-04-28',
#  '1980-04-29',
#  '1980-04-30',
#  '1980-05-01',
#  '1980-05-02',
#  '1980-05-03',
#  '1980-05-04',
#  '1980-05-05',
#  '1980-05-06',
#  '1980-05-07',
#  '1980-05-08',
#  '1980-05-09',
#  '1980-05-10',
#  '1980-05-11',
#  '1980-05-12',
#  '1980-05-13',
#  '1980-05-14',
#  '1980-05-15',
#  '1980-05-16',
#  '1980-05-17',
#  '1980-05-18',
#  '1980-05-19',
#  '1980-05-20',
#  '1980-05-21',
#  '1980-05-22',
#  '1980-05-23',
#  '1980-05-24',
#  '1980-05-25',
#  '1980-05-26',
#  '1980-05-27',
#  '1980-05-28',
#  '1980-05-29',
#  '1980-05-30',
#  '1980-05-31',
#  '1980-06-01',
#  '1980-06-02',
#  '1980-06-03',
#  '1980-06-04',
#  '1980-06-05',
#  '1980-06-06',
#  '1980-06-07',
#  '1980-06-08',
#  '1980-06-09',
#  '1980-06-10',
#  '1980-06-11',
#  '1980-06-12',
#  '1980-06-13',
#  '1980-06-14',
#  '1980-06-15',
#  '1980-06-16',
#  '1980-06-17',
#  '1980-06-18',
#  '1980-06-19',
#  '1980-06-20',
#  '1980-06-21',
#  '1980-06-22',
#  '1980-06-23',
#  '1980-06-24',
#  '1980-06-25',
#  '1980-06-26',
#  '1980-06-27',
#  '1980-06-28',
#  '1980-06-29',
#  '1980-06-30',
#  '1980-07-01',
#  '1980-07-02',
#  '1980-07-03',
#  '1980-07-04',
#  '1980-07-05',
#  '1980-07-06',
#  '1980-07-07',
#  '1980-07-08',
#  '1980-07-09',
#  '1980-07-10',
#  '1980-07-11',
#  '1980-07-12',
#  '1980-07-13',
#  '1980-07-14',
#  '1980-07-15',
#  '1980-07-16',
#  '1980-07-17',
#  '1980-07-18',
#  '1980-07-19',
#  '1980-07-20',
#  '1980-07-21',
#  '1980-07-22',
#  '1980-07-23',
#  '1980-07-24',
#  '1980-07-25',
#  '1980-07-26',
#  '1980-07-27',
#  '1980-07-28',
#  '1980-07-29',
#  '1980-07-30',
#  '1980-07-31',
#  '1980-08-01',
#  '1980-08-02',
#  '1980-08-03',
#  '1980-08-04',
#  '1980-08-05',
#  '1980-08-06',
#  '1980-08-07',
#  '1980-08-08',
#  '1980-08-09',
#  '1980-08-10',
#  '1980-08-11',
#  '1980-08-12',
#  '1980-08-13',
#  '1980-08-14',
#  '1980-08-15',
#  '1980-08-16',
#  '1980-08-17',
#  '1980-08-18',
#  '1980-08-19',
#  '1980-08-20',
#  '1980-08-21',
#  '1980-08-22',
#  '1980-08-23',
#  '1980-08-24',
#  '1980-08-25',
#  '1980-08-26',
#  '1980-08-27',
#  '1980-08-28',
#  '1980-08-29',
#  '1980-08-30',
#  '1980-08-31',
#  '1980-09-01',
#  '1980-09-02',
#  '1980-09-03',
#  '1980-09-04',
#  '1980-09-05',
#  '1980-09-06',
#  '1980-09-07',
#  '1980-09-08',
#  '1980-09-09',
#  '1980-09-10',
#  '1980-09-11',
#  '1980-09-12',
#  '1980-09-13',
#  '1980-09-14',
#  '1980-09-15',
#  '1980-09-16',
#  '1980-09-17',
#  '1980-09-18',
#  '1980-09-19',
#  '1980-09-20',
#  '1980-09-21',
#  '1980-09-22',
#  '1980-09-23',
#  '1980-09-24',
#  '1980-09-25',
#  '1980-09-26',
#  '1980-09-27',
#  '1980-09-28',
#  '1980-09-29',
#  '1980-09-30',
#  '1980-10-01',
#  '1980-10-02',
#  '1980-10-03',
#  '1980-10-04',
#  '1980-10-05',
#  '1980-10-06',
#  '1980-10-07',
#  '1980-10-08',
#  '1980-10-09',
#  '1980-10-10',
#  '1980-10-11',
#  '1980-10-12',
#  '1980-10-13',
#  '1980-10-14',
#  '1980-10-15',
#  '1980-10-16',
#  '1980-10-17',
#  '1980-10-18',
#  '1980-10-19',
#  '1980-10-20',
#  '1980-10-21',
#  '1980-10-22',
#  '1980-10-23',
#  '1980-10-24',
#  '1980-10-25',
#  '1980-10-26',
#  '1980-10-27',
#  '1980-10-28',
#  '1980-10-29',
#  '1980-10-30',
#  '1980-10-31',
#  '1980-11-01',
#  '1980-11-02',
#  '1980-11-03',
#  '1980-11-04',
#  '1980-11-05',
#  '1980-11-06',
#  '1980-11-07',
#  '1980-11-08',
#  '1980-11-09',
#  '1980-11-10',
#  '1980-11-11',
#  '1980-11-12',
#  '1980-11-13',
#  '1980-11-14',
#  '1980-11-15',
#  '1980-11-16',
#  '1980-11-17',
#  '1980-11-18',
#  '1980-11-19',
#  '1980-11-20',
#  '1980-11-21',
#  '1980-11-22',
#  '1980-11-23',
#  '1980-11-24',
#  '1980-11-25',
#  '1980-11-26',
#  '1980-11-27',
#  '1980-11-28',
#  '1980-11-29',
#  '1980-11-30',
#  '1980-12-01',
#  '1980-12-02',
#  '1980-12-03',
#  '1980-12-04',
#  '1980-12-05',
#  '1980-12-06',
#  '1980-12-07',
#  '1980-12-08',
#  '1980-12-09',
#  '1980-12-10',
#  '1980-12-11',
#  '1980-12-12',
#  '1980-12-13',
#  '1980-12-14',
#  '1980-12-15',
#  '1980-12-16',
#  '1980-12-17',
#  '1980-12-18',
#  '1980-12-19',
#  '1980-12-20',
#  '1980-12-21',
#  '1980-12-22',
#  '1980-12-23',
#  '1980-12-24',
#  '1980-12-25',
#  '1980-12-26',
#  '1980-12-27',
#  '1980-12-28',
#  '1980-12-29',
#  '1980-12-30',
#  '1980-12-31',
#  '1981-01-01',
#  '1981-01-02',
#  '1981-01-03',
#  '1981-01-04',
#  '1981-01-05',
#  '1981-01-06',
#  '1981-01-07',
tasks      | elapsed:  4.1min
# [Parallel(n_jobs=128)]: Done 259 tasks      | elapsed:  4.1min
# [Parallel(n_jobs=128)]: Done 260 tasks      | elapsed:  4.1min
# [Parallel(n_jobs=128)]: Done 261 tasks      | elapsed:  4.1min
# [Parallel(n_jobs=128)]: Done 262 tasks      | elapsed:  4.1min
# [Parallel(n_jobs=128)]: Done 263 tasks      | elapsed:  4.1min
# [Parallel(n_jobs=128)]: Done 264 tasks      | elapsed:  4.1min
# [Parallel(n_jobs=128)]: Done 265 tasks      | elapsed:  4.1min
# [Parallel(n_jobs=128)]: Done 266 tasks      | elapsed:  4.2min
# [Parallel(n_jobs=128)]: Done 267 tasks      | elapsed:  4.2min
# [Parallel(n_jobs=128)]: Done 268 tasks      | elapsed:  4.2min
# [Parallel(n_jobs=128)]: Done 269 tasks      | elapsed:  4.2min
# [Parallel(n_jobs=128)]: Done 270 tasks      | elapsed:  4.2min
# [Parallel(n_jobs=128)]: Done 271 tasks      | elapsed:  4.2min
# [Parallel(n_jobs=128)]: Done 272 tasks      | elapsed:  4.2min
# [Parallel(n_jobs=128)]: Done 273 tasks      | elapsed:  4.3min
# [Parallel(n_jobs=128)]: Done 274 tasks      | elapsed:  4.3min
# [Parallel(n_jobs=128)]: Done 275 tasks      | elapsed:  4.3min
# [Parallel(n_jobs=128)]: Done 276 tasks      | elapsed:  4.3min
# [Parallel(n_jobs=128)]: Done 277 tasks      | elapsed:  4.5min
# [Parallel(n_jobs=128)]: Done 278 tasks      | elapsed:  4.6min
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 3
#       1 from rainproj.era_arco import run_download3
# ----> 3 run_download3()
#
# File /work/07989/clin265/ls6/rainproj/rainproj/era_arco.py:124, in run_download3()
#     122 def process_day(date,sub_ds):
#     123     sub_ds.pipe(RainReader2.resample_daily).to_netcdf(era_stage1_dir/f'era_{date}.nc')
# --> 124 tasks = joblib.Parallel(n_jobs=os.cpu_count(),verbose=100,timeout=99999)(joblib.delayed(process_day)(date,ds.sel(time=date)) for date in date_strings)
#
# File /work/07989/clin265/ls6/miniforge3/envs/netcdf/lib/python3.13/site-packages/joblib/parallel.py:2072, in Parallel.__call__(self, iterable)
#    2066 # The first item from the output is blank, but it makes the interpreter
#    2067 # progress until it enters the Try/Except block of the generator and
#    2068 # reaches the first `yield` statement. This starts the asynchronous
#    2069 # dispatch of the tasks to the workers.
#    2070 next(output)
# -> 2072 return output if self.return_generator else list(output)
#
# File /work/07989/clin265/ls6/miniforge3/envs/netcdf/lib/python3.13/site-packages/joblib/parallel.py:1682, in Parallel._get_outputs(self, iterator, pre_dispatch)
#    1679     yield
#    1681     with self._backend.retrieval_context():
# -> 1682         yield from self._retrieve()
#    1684 except GeneratorExit:
#    1685     # The generator has been garbage collected before being fully
#    1686     # consumed. This aborts the remaining tasks if possible and warn
#    1687     # the user if necessary.
#    1688     self._exception = True
#
# File /work/07989/clin265/ls6/miniforge3/envs/netcdf/lib/python3.13/site-packages/joblib/parallel.py:1800, in Parallel._retrieve(self)
#    1789 if self.return_ordered:
#    1790     # Case ordered: wait for completion (or error) of the next job
#    1791     # that have been dispatched and not retrieved yet. If no job
#    (...)   1795     # control only have to be done on the amount of time the next
#    1796     # dispatched job is pending.
#    1797     if (nb_jobs == 0) or (
#    1798         self._jobs[0].get_status(timeout=self.timeout) == TASK_PENDING
#    1799     ):
# -> 1800         time.sleep(0.01)
#    1801         continue
#    1803 elif nb_jobs == 0:
#    1804     # Case unordered: jobs are added to the list of jobs to
#    1805     # retrieve `self._jobs` only once completed or in error, which
#    (...)   1811     # timeouts before any other dispatched job has completed and
#    1812     # been added to `self._jobs` to be retrieved.
#
# KeyboardInterrupt:

# %%
# !hostname
# Out:
# c303-006.ls6.tacc.utexas.edu

# %% [markdown]
# This notebook is for debugging only. There is a bash script that will execute the command below.

# %%
# From htop, roughly estimated that 20 task will consume 80 GB, note that TACC nodes have 251 GB, probably safe to use 40 workers avoid memory overload. Or maybe even stick to 20 since this is an IO bound task. Cpus will wait until all data is got,.
from rainproj.era_arco import run_download2

run_download2()

# %%
from rainproj.rainreader2 import StopExecution

raise StopExecution

# %% [markdown]
# ## Unused Code
# ***

# %%
import os

import dask
from xarray.groupers import TimeResampler

from rainproj.era_arco import ERA
from rainproj.rainreader2 import RainReader2

WORK = os.environ.get('WORK')
SCRATCH = os.environ.get('SCRATCH')

# %%
ERA.load_ar_total_precipitation()
# Out:
# <xarray.DataArray 'total_precipitation' (time: 1323648, latitude: 721,
#                                          longitude: 1440)> Size: 5TB
# dask.array<open_dataset-total_precipitation, shape=(1323648, 721, 1440), dtype=float32, chunksize=(48, 721, 1440), chunktype=numpy.ndarray>
# Coordinates:
#   * latitude   (latitude) float32 3kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#   * longitude  (longitude) float32 6kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#   * time       (time) datetime64[ns] 11MB 1900-01-01 ... 2050-12-31T23:00:00
# Attributes:
#     long_name:   Total precipitation
#     short_name:  tp
#     units:       m

# %%
# {'time': TimeResampler("MS")}
ds_daily = ERA.load_ar_total_precipitation().sortby('latitude').rename({'latitude':'lat','longitude':'lon'}).pipe(RainReader2.slice_rain).chunk(time=TimeResampler("MS")).pipe(RainReader2.resample_daily)
month_year_groups = ds_daily.groupby(time=TimeResampler("MS"))

def process_month(month_year_ds):
    df = month_year_ds.stack(idx=("time","lat","lon")).to_pandas().to_frame()
    month_year = df.index.get_level_values('time')[0].strftime('%Y-%m')
    df.to_parquet(f'{SCRATCH}/hindcast/era2/{month_year}.parquet')

# tasks = [dask.delayed(process_month)(month_year_ds) for month_year_ds in month_year_groups]

# dask.compute(tasks)

# %%
for time,mo_yr in month_year_groups:
    time = time
    break

# %%
from datetime import datetime
import pandas as pd
pd.Timestamp(time).strftime('%Y-%m')
# Out:
# '1978-12'

# %%
ERA.load_ar_total_precipitation().sortby('latitude').rename({'latitude':'lat','longitude':'lon'}).pipe(RainReader2.slice_rain).pipe(RainReader2.resample_daily)
# Out:
# <xarray.DataArray 'total_precipitation' (time: 16804, lat: 99, lon: 233)> Size: 2GB
# dask.array<stack, shape=(16804, 99, 233), dtype=float32, chunksize=(1, 99, 233), chunktype=numpy.ndarray>
# Coordinates:
#   * lat      (lat) float32 396B 25.0 25.25 25.5 25.75 ... 48.75 49.0 49.25 49.5
#   * lon      (lon) float32 932B 235.0 235.2 235.5 235.8 ... 292.5 292.8 293.0
#   * time     (time) datetime64[ns] 134kB 1978-12-31 1979-01-01 ... 2025-01-01
# Attributes:
#     long_name:   24-Hour Total Precipitation
#     short_name:  tp
#     units:       m

# %%
ERA.load_ar_total_precipitation().sortby('latitude').rename({'latitude':'lat','longitude':'lon'}).pipe(RainReader2.slice_rain).chunk(time=TimeResampler("MS")).pipe(RainReader2.resample_daily)
# Out:
# <xarray.DataArray 'total_precipitation' (time: 16804, lat: 99, lon: 233)> Size: 2GB
# dask.array<stack, shape=(16804, 99, 233), dtype=float32, chunksize=(1, 99, 233), chunktype=numpy.ndarray>
# Coordinates:
#   * lat      (lat) float32 396B 25.0 25.25 25.5 25.75 ... 48.75 49.0 49.25 49.5
#   * lon      (lon) float32 932B 235.0 235.2 235.5 235.8 ... 292.5 292.8 293.0
#   * time     (time) datetime64[ns] 134kB 1978-12-31 1979-01-01 ... 2025-01-01
# Attributes:
#     long_name:   24-Hour Total Precipitation
#     short_name:  tp
#     units:       m

# %%
import numpy as np
# https://docs.xarray.dev/en/stable/user-guide/groupby.html

process_month(month_year_groups[np.datetime64('1979-12-01T00:00:00.000000000')])

# %%
# Chunking can be useful
# ds_daily = ds.pipe(RainReader2.resample_daily).chunk(time=TimeResampler("MS"))

# %%
# import pandas as pd
# time =ds_daily.time[0]
# date = str(time.values).split('T')[0]
# tt = pd.concat({time.values:ds_daily.sel(time=time).stack(idx=("lat","lon")).to_series()},names=['date'])
# tt
# Out:
# date        lat   lon
# 1978-12-31  25.0  235.00    0.000123
#                   235.25    0.000085
#                   235.50    0.000116
#                   235.75    0.000162
#                   236.00    0.000189
#                               ...
#             49.5  292.00    0.001550
#                   292.25    0.001651
#                   292.50    0.001742
#                   292.75    0.001430
#                   293.00    0.001056
# Name: total_precipitation, Length: 23067, dtype: float32

# %%
from joblib import Parallel, delayed
import os

def run(ds,time):
    filename_date = str(time.values).split('T')[0]
    stacked = pd.concat({time.values:ds.sel(time=time).stack(idx=("lat","lon")).to_series()},names=['date']).to_frame()
    stacked.to_parquet(f'{SCRATCH}/hindcast/era/{filename_date}.parquet')
    # return stacked
    
parallel = Parallel(n_jobs=os.cpu_count()-1)
silent = parallel(delayed(run)(ds_daily,time) for time in ds_daily.time)

# [for i,_ in enumerate(ds_daily.time)]
# Out:
# Failed to connect to the remote Jupyter Server 'http://c307-005.ls6.tacc.utexas.edu:8888/'. Verify the server is running and reachable.

# %%
ds_daily.sel(time=ds_daily.time[0]).stack(idx=("lat","lon")).to_series()
# Out:
# lat   lon
# 25.0  235.00    0.000123
#       235.25    0.000085
#       235.50    0.000116
#       235.75    0.000162
#       236.00    0.000189
#                   ...
# 49.5  292.00    0.001550
#       292.25    0.001651
#       292.50    0.001742
#       292.75    0.001430
#       293.00    0.001056
# Name: total_precipitation, Length: 23067, dtype: float32

# %%
ds_stack = ds_daily.stack(idx=("lat","lon",)).to_series()

# %%
ds_stack
# Out:
# <xarray.DataArray 'total_precipitation' (idx: 387617868)> Size: 2GB
# dask.array<reshape, shape=(387617868,), dtype=float32, chunksize=(33608,), chunktype=numpy.ndarray>
# Coordinates:
#   * idx      (idx) object 3GB MultiIndex
#   * lat      (idx) float32 2GB 25.0 25.0 25.0 25.0 25.0 ... 49.5 49.5 49.5 49.5
#   * lon      (idx) float32 2GB 235.0 235.0 235.0 235.0 ... 293.0 293.0 293.0
#   * time     (idx) datetime64[ns] 3GB 1978-12-31 1979-01-01 ... 2025-01-01
# Attributes:
#     long_name:   24-Hour Total Precipitation
#     short_name:  tp
#     units:       m

# %%
ds_subset = ds.sel(latitude=slice(49.5904,24.9493),longitude=slice(360-125.0011,360-66.9326),time=slice('1978-12-31','2025-01-01'))

# %%
ds.sel(latitude=slice(49.5904,24.9493),longitude=slice(360-125.0011,360-66.9326),time=slice('1978-12-31','2025-01-01'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 ds.sel(latitude=slice(49.5904,24.9493),longitude=slice(360-125.0011,360-66.9326),time=slice('1978-12-31','2025-01-01'))
#
# NameError: name 'ds' is not defined

# %%
ds_subset
# Out:
# <xarray.DataArray 'total_precipitation' (time: 403296, latitude: 99,
#                                          longitude: 233)> Size: 37GB
# dask.array<getitem, shape=(403296, 99, 233), dtype=float32, chunksize=(48, 99, 233), chunktype=numpy.ndarray>
# Coordinates:
#   * latitude   (latitude) float32 396B 49.5 49.25 49.0 48.75 ... 25.5 25.25 25.0
#   * longitude  (longitude) float32 932B 235.0 235.2 235.5 ... 292.5 292.8 293.0
#   * time       (time) datetime64[ns] 3MB 1978-12-31 ... 2025-01-01T23:00:00
# Attributes:
#     long_name:   Total precipitation
#     short_name:  tp
#     units:       m

# %%
ds_daily = ds_subset.resample(time='1D').sum()

# %%
stacked = ds_daily.stack(idx=("latitude","longitude","time")).to_series().compute()

# %%
ds_daily.to_netcdf('data/era5_total_precipitation.nc')

# %%
import zarr
from numcodecs.zarr3 import Blosc

encoding = {
    "total_precipitation": {
        "compressor": Blosc(
            cname="zstd",
            clevel=6,
        ),
    }
}
for coord in ds_daily.coords:
    encoding[coord] = {"compressors": None}
ds_daily.to_zarr('data/era5_total_precipitation.zarr',mode='w',encoding=encoding)
